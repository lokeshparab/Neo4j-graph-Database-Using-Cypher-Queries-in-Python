# %% [markdown]
# # Installing and Loading Libraries

# %%
# !pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-5.5.0.tar.gz (171 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: pytz in e:\anaconda\lib\site-packages (from neo4j) (2021.3)
# Building wheels for collected packages: neo4j
#   Building wheel for neo4j (PEP 517): started
#   Building wheel for neo4j (PEP 517): finished with status 'done'
#   Created wheel for neo4j: filename=neo4j-5.5.0-py3-none-any.whl size=237218 sha256=9c26139b0d3a48d2f4d94977be182628cc310e9ab57421a3766cfde9c442c501
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\cf\f1\0f\c822c00653dbdd315ff394f981fde6e3852bc281e01964216c
# Successfully built neo4j
# Installing collected packages: neo4j
# Successfully installed neo4j-5.5.0

# %% [markdown]
# # Creating Function

# %%
import pandas as  pd

# %%
from neo4j import GraphDatabase
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
def result_to_dataframe(result):
    
    data = { column:[] for column, _ in result[0].items()}
    
    for record in result:
        
        for col, val in record.items():
            
            data[col].append(val)
    
    return pd.DataFrame(data)

# %%
db =  Neo4jConnection("bolt://localhost:7687", "neo4j", "password")

# %% [markdown]
# # Query 1 Person role in that Movie

# %%
q  = '''match (p:Person) -[r]-> (m:Movie)
        return p.name as person ,type(r) as role ,m.title as movie'''

result = db.query(q)

result_to_dataframe(result)
# Out:
#               person      role                  movie
# 0        Emil Eifrem  ACTED_IN             The Matrix
# 1        Joel Silver  PRODUCED             The Matrix
# 2     Lana Wachowski  DIRECTED             The Matrix
# 3     Andy Wachowski  DIRECTED             The Matrix
# 4       Hugo Weaving  ACTED_IN             The Matrix
# ..               ...       ...                    ...
# 242      Bill Paxton  ACTED_IN  A League of Their Own
# 243        Tom Hanks  ACTED_IN  A League of Their Own
# 244  Rosie O'Donnell  ACTED_IN  A League of Their Own
# 245      Geena Davis  ACTED_IN  A League of Their Own
# 246          Madonna  ACTED_IN  A League of Their Own
#
# [247 rows x 3 columns]

# %% [markdown]
# # Query 2 : List of Movie

# %%
q  = '''match (m:Movie)
        return m.title as movie, m.tagline as tagline,m.released as released'''

result = db.query(q)
result_to_dataframe(result)
# Out:
#                               movie  \
# 0                        The Matrix
# 1               The Matrix Reloaded
# 2            The Matrix Revolutions
# 3              The Devil's Advocate
# 4                    A Few Good Men
# 5                           Top Gun
# 6                     Jerry Maguire
# 7                       Stand By Me
# 8                As Good as It Gets
# 9              What Dreams May Come
# 10           Snow Falling on Cedars
# 11                  You've Got Mail
# 12             Sleepless in Seattle
# 13           Joe Versus the Volcano
# 14             When Harry Met Sally
# 15                That Thing You Do
# 16                 The Replacements
# 17                       RescueDawn
# 18                     The Birdcage
# 19                       Unforgiven
# 20                  Johnny Mnemonic
# 21                      Cloud Atlas
# 22                The Da Vinci Code
# 23                   V for Vendetta
# 24                      Speed Racer
# 25                   Ninja Assassin
# 26                   The Green Mile
# 27                      Frost/Nixon
# 28                            Hoffa
# 29                        Apollo 13
# 30                          Twister
# 31                        Cast Away
# 32  One Flew Over the Cuckoo's Nest
# 33           Something's Gotta Give
# 34                 Bicentennial Man
# 35             Charlie Wilson's War
# 36                The Polar Express
# 37            A League of Their Own
#
#                                               tagline  released
# 0                           Welcome to the Real World      1999
# 1                                      Free your mind      2003
# 2          Everything that has a beginning has an end      2003
# 3                           Evil has its winning ways      1997
# 4   In the heart of the nation's capital, in a cou...      1992
# 5                I feel the need, the need for speed.      1986
# 6                    The rest of his life begins now.      2000
# 7   For some, it's the last real taste of innocenc...      1986
# 8   A comedy from the heart that goes for the throat.      1997
# 9   After life there is more. The end is just the ...      1998
# 10                         First loves last. Forever.      1999
# 11                At odds in life... in love on-line.      1998
# 12  What if someone you never met, someone you nev...      1993
# 13          A story of love, lava and burning desire.      1990
# 14                At odds in life... in love on-line.      1998
# 15  In every life there comes a time when that thi...      1996
# 16  Pain heals, Chicks dig scars... Glory lasts fo...      2000
# 17  Based on the extraordinary true story of one m...      2006
# 18                                    Come as you are      1996
# 19              It's a hell of a thing, killing a man      1992
# 20  The hottest data on earth. In the coolest head...      1995
# 21                            Everything is connected      2012
# 22                                    Break The Codes      2006
# 23                                  Freedom! Forever!      2006
# 24                                Speed has no limits      2008
# 25       Prepare to enter a secret world of assassins      2009
# 26                   Walk a mile you'll never forget.      1999
# 27     400 million people were waiting for the truth.      2008
# 28             He didn't want law. He wanted justice.      1992
# 29                        Houston, we have a problem.      1995
# 30                    Don't Breathe. Don't Look Back.      1996
# 31      At the edge of the world, his journey begins.      2000
# 32            If he's crazy, what does that make you?      1975
# 33                                               None      2003
# 34  One robot's 200 year journey to become an ordi...      1999
# 35  A stiff drink. A little mascara. A lot of nerv...      2007
# 36                       This Holiday Season… Believe      2004
# 37  Once in a lifetime you get a chance to do some...      1992

# %% [markdown]
# # Query 3 : List of Person  along with roles

# %%
q  = '''match (p:Person) -[r] -> (m:Movie)
        return p.name as person , p.born as birth_year, type(r) as roles'''

result = db.query(q)
result_to_dataframe(result)
# Out:
#               person  birth_year     roles
# 0        Emil Eifrem      1978.0  ACTED_IN
# 1        Joel Silver      1952.0  PRODUCED
# 2     Lana Wachowski      1965.0  DIRECTED
# 3     Andy Wachowski      1967.0  DIRECTED
# 4       Hugo Weaving      1960.0  ACTED_IN
# ..               ...         ...       ...
# 242      Bill Paxton      1955.0  ACTED_IN
# 243        Tom Hanks      1956.0  ACTED_IN
# 244  Rosie O'Donnell      1962.0  ACTED_IN
# 245      Geena Davis      1956.0  ACTED_IN
# 246          Madonna      1954.0  ACTED_IN
#
# [247 rows x 3 columns]

# %% [markdown]
# # Query 4 : Top 5 People who worked most Number of movies as Director

# %%
q  = '''match (p) -[:DIRECTED]- (m)
        with p ,count(m) as no_of_movies
        return p.name as Person, no_of_movies
        order by no_of_movies desc
        Limit 5'''

result = db.query(q)
result_to_dataframe(result)
# Out:
#            Person  no_of_movies
# 0  Andy Wachowski             5
# 1  Lana Wachowski             5
# 2            None             3
# 3      Rob Reiner             3
# 4      Ron Howard             3

# %% [markdown]
# # Query 5: List of Person who worked as Director and Producerd in Same Movie
# # ![Picture](Pictures/ql.png)

# %%
q  = '''match(p:Person) -[:DIRECTED]-> (m:Movie)
        match(p) -[:PRODUCED] -> (m)
        return p.name as person, p.born as birth_year, m.title as movie, m.released'''

result = db.query(q)
result_to_csv(result)
# Out:
#           person  birth_year                   movie  m.released
# 0  Cameron Crowe        1957           Jerry Maguire        2000
# 1     Rob Reiner        1947    When Harry Met Sally        1998
# 2   Nancy Meyers        1949  Something's Gotta Give        2003

# %% [markdown]
# # Query 6: Person of worked more than 6 movies . Give names of person and movies he/ she worked
#
# ![Picture](Pictures/q6.png)

# %%
q =  """match (p:Person) --> (m:Movie)
        with p ,collect(m) as movies
        where size(movies) > 6
        UNWIND movies as m
        return p.name,m.title"""

result = db.query(q)
result_to_dataframe(result)
# Out:
#             p.name                 m.title
# 0   Lana Wachowski              The Matrix
# 1   Lana Wachowski     The Matrix Reloaded
# 2   Lana Wachowski  The Matrix Revolutions
# 3   Lana Wachowski             Cloud Atlas
# 4   Lana Wachowski          V for Vendetta
# 5   Lana Wachowski          V for Vendetta
# 6   Lana Wachowski             Speed Racer
# 7   Lana Wachowski             Speed Racer
# 8   Lana Wachowski          Ninja Assassin
# 9   Andy Wachowski              The Matrix
# 10  Andy Wachowski     The Matrix Reloaded
# 11  Andy Wachowski  The Matrix Revolutions
# 12  Andy Wachowski             Cloud Atlas
# 13  Andy Wachowski          V for Vendetta
# 14  Andy Wachowski          V for Vendetta
# 15  Andy Wachowski             Speed Racer
# 16  Andy Wachowski             Speed Racer
# 17  Andy Wachowski          Ninja Assassin
# 18    Keanu Reeves              The Matrix
# 19    Keanu Reeves     The Matrix Reloaded
# 20    Keanu Reeves  The Matrix Revolutions
# 21    Keanu Reeves    The Devil's Advocate
# 22    Keanu Reeves        The Replacements
# 23    Keanu Reeves         Johnny Mnemonic
# 24    Keanu Reeves  Something's Gotta Give
# 25       Tom Hanks         You've Got Mail
# 26       Tom Hanks    Sleepless in Seattle
# 27       Tom Hanks  Joe Versus the Volcano
# 28       Tom Hanks       That Thing You Do
# 29       Tom Hanks       That Thing You Do
# 30       Tom Hanks             Cloud Atlas
# 31       Tom Hanks       The Da Vinci Code
# 32       Tom Hanks          The Green Mile
# 33       Tom Hanks               Apollo 13
# 34       Tom Hanks               Cast Away
# 35       Tom Hanks    Charlie Wilson's War
# 36       Tom Hanks       The Polar Express
# 37       Tom Hanks   A League of Their Own

# %%
def graphs_to_csv(result):
    
    dct = {}
    
    for var in result:
        dct = { k[0]:{} for k in var.items() }
        break
        
    
    for i in result:
        d = i.items()
        for var , data in d:
            label = ' '.join(list(data.labels))
            dct[var][label] = {}
            properties = data._properties.keys()
            
            if not label in dct:
                dct[var][label] = { k : [] for k in properties }

            else:
                for i in properties:
                    if not i in dct[label]:
                        dct[var][label][i] = []
            
    for i in result:
        
        d = i.items()
        for var , data in d:
            label = ' '.join(list(data.labels))
            properties = data._properties
            
            for k in dct[var][label] :

                v = properties.get(k,float('nan'))

                dct[var][label][k].append(v)
    
    for var in dct:
        for label , v in dct[var].items():
            dct[var][label] = pd.DataFrame(v)
        
    return dct
